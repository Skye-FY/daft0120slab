# %%
# inclass quiz

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-10,10,100)
y = np.cos(x)

plt.plot(x, y, label= 'cosine curve')
plt.title('Cosine Graph')
plt.show()

# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

import seaborn as sns
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x,y,linewidth=1.5, label='Linear',linestyle='dashed',marker='*')
plt.plot(x,z,linewidth=.5,label='Parabola',linestyle='solid', marker='^')
plt.title('Plot Linear and Parabola Models')
plt.legend()
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig, ax = plt.subplots(1,2)
ax[0].plot(x,y,label='f(x)=2x',linestyle='dashed',marker='*')
ax[1].plot(x,z,label= 'f(x)=x^2',linestyle='solid', marker='^')
ax[0].set_title('Linear Model')
ax[1].set_title('Parabola Model')
ax[0].legend()
ax[1].legend()
plt.legend()
plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
fig, ax = plt.subplots(1,2,figsize=(25,12.5))
ax[0].plot(x,y,label='f(x)=2x',linestyle='dashed',marker='*')
ax[1].plot(x,z,label= 'f(x)=x^2',linestyle='solid',color='orange', marker='^')
ax[0].set_title('Linear Model',fontsize=60,fontweight='heavy',color='blue')
ax[1].set_title('Parabola Model',fontsize=60,fontweight='heavy',color='orange')
ax[0].legend()
ax[1].legend()
plt.show()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
x=np.linspace(1,10)
y1=x**2
y2=np.exp(x)
fig, bx = plt.subplots(1,2,figsize=(26,13))
bx[0].plot(x,y1,color='green',label='Parabola')
bx[1].plot(x,y2,color='purple',label='Exponential')
bx[0].set_title('Prabola Model',fontsize=60,fontweight='heavy',color='green')
bx[1].set_title('Exponential Curve',fontsize=60,fontweight='heavy',color='purple')
bx[1].set_xscale('log')
bx[1].set_yscale('log')
plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
x=np.linspace(1,10)
y1=x**2
y2=np.exp(x)
fig, bx = plt.subplots(1,2,figsize=(26,13))
bx[0].plot(x,y1,color='green',label='Parabola')
bx[1].plot(x,y2,color='purple',label='Exponential')
bx[0].set_title('Prabola Model',fontsize=60,fontweight='heavy',color='green')
bx[1].set_title('Exponential Curve',fontsize=60,fontweight='heavy',color='purple')
bx[0].legend()
bx[1].legend()
bx[1].set_xscale('log')
bx[1].set_yscale('log')
plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit = pd.read_csv('../../../../lessons/data/Fitbit2.csv')
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  MinutesOfSleep  MinutesOfBeingAwake  NumberOfAwakings  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here
fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(12,4))

med_step_mon = fitbit.groupby('Months_encoded').agg({'Steps':'median'})

plt.sca(ax[0])
plt.plot(list(med_step_mon.index),med_step_mon,color='green',label='Monthly Median Steps')
plt.xticks(np.arange(1,13),list(med_step_mon.index),color='green')
plt.title('MEDIAN STEPS BY MONTH_ENCODED',fontsize=10,color='green')

# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here

med_step_wkn = fitbit.groupby('Work_or_Weekend').agg({'Steps':'median'})

plt.sca(ax[1])
plt.plot(med_step_wkn.index,med_step_wkn,color='blue',label='Median Steps on Weekends/During Week')
plt.xticks(np.arange(0,2),['Weekend','Week'],color='blue')
plt.title('MEDIAN STEPS BY WORK_OR_WEEKEND',fontsize=10,color='blue')

plt.show()

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
def pltScatter(df,colvalue,targetlst):
    for i in range(len(targetlst)):
        plt.scatter(df[targetlst[i]].index,df[colvalue],label='%s'%targetlst[i])
        #     plt.xticks(np.arange(0,len(df[colname])), list(df[colname].index))
        plt.title('%s vs %s' % (targetlst[i],str(colvalue)),fontsize=10)
        plt.legend()
        plt.show()
        plt.savefig('../figures/fitbit_%s.png' % targetlst[i])

    

lst = ['Minutes Lightly Active','Minutes Very Active','Minutes Sedentary']
pltScatter(fitbit,'Steps',lst)

# %%
# your code here
def pltScatter(ax, df, x, y):#,targetlst):
#     for i in range(len(targetlst)):
    ax.scatter(df[x],df[y])
    #     plt.xticks(np.arange(0,len(df[colname])), list(df[colname].index))
    ax.set_title(x)
    plt.savefig('../figures/fitbit_.png')

fig, ax = plt.subplots(1,3, figsize = (30,10))
lst = ['Minutes Lightly Active','Minutes Very Active','Minutes Sedentary']
for i in range(3):
    pltScatter(ax[i],fitbit, lst[i], 'Steps')

# %%
# import os
# os.mkdir('../figures')

fig.savefig('../figures/fitbit.png')

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv('../../../../lessons/data/titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
t_num = titanic.select_dtypes(include=np.number)
t_num.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1       0.0       3  22.0      1      0   7.2500
# 1            2       1.0       1  38.0      1      0  71.2833
# 2            3       1.0       3  26.0      0      0   7.9250
# 3            4       1.0       1  35.0      1      0  53.1000
# 4            5       0.0       3  35.0      0      0   8.0500

# %%
# CATEGORICAL VARIABLES
# your code here
t_cat = titanic.select_dtypes(include='object')
t_cat.head()
# Out:
#                                                 Name  Gender  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S
# 3            113803  C123        S
# 4            373450    U0        S

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here

fig, cx = plt.subplots(figsize=(12,6))
sns.set()

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
titanic['Age'].value_counts()
# Out:
# 24.000000    47
# 22.000000    43
# 21.000000    41
# 30.000000    40
# 18.000000    39
#              ..
# 36.874665     1
# 23.095064     1
# 38.250015     1
# 32.162403     1
# 31.080075     1
# Name: Age, Length: 193, dtype: int64

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
titanic['Age'].hist(bins=10)
titanic['Age'].hist(bins=20)
titanic['Age'].hist(bins=50)

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
"""
'''
It does in the way that more bins displays more details and makes the distribution smoother
but not in the way that it makes any difference on the distribution itself.
'''

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.distplot(titanic['Age'])

# %%
sns.distplot(titanic['Age'],bins=10)
sns.distplot(titanic['Age'],bins=20)
sns.distplot(titanic['Age'],bins=50)

# %%
sns.catplot(y='Age',hue='Pclass',x='Survived',data=titanic)

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
gen = list(titanic['Gender'].unique())
size = [titanic['Gender'].value_counts()['male'].sum()/titanic['Gender'].value_counts().sum(),
        titanic['Gender'].value_counts()['female'].sum()/titanic['Gender'].value_counts().sum()]
plt.pie(size,labels=gen,autopct='%.2f',explode=[0,.05],colors=['gray','pink'])
# Out:
# ([<matplotlib.patches.Wedge at 0x24e8fbdcfd0>,
# ...
#  [Text(-0.48083677220945115, 0.9893411941747885, 'male'),
#   Text(0.5026928922888523, -1.0343112955209706, 'female')],
#  [Text(-0.262274603023337, 0.5396406513680664, '64.40'),
#   Text(0.28413076520674263, -0.5846107322509833, '35.60')])

# %%
# Method 2 - seaborn
# your code here

t_gen = pd.DataFrame(titanic['Gender'].value_counts()).reset_index()

fig, ex = plt.subplots(figsize=(12,6))
sns.barplot(x = 'index', y = 'Gender', ax=ex, data=t_gen)

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
t_pcls = pd.DataFrame(titanic['Pclass'].value_counts()).reset_index()
sns.barplot(x='index',y='Pclass',data=t_pcls)

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

sns.boxplot(titanic['Age'])

# %%
"""
your comments here
"""

'''
majority aged between 20 and 40
''

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
some really old passenger was on the ship 
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.violinplot(titanic['Age'])

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""
'''
people aged above 40 were more than those aged below 20
'''

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
plt.scatter(titanic['Age'],titanic['Fare'])

# %%
t_fa = titanic[['Fare','Age']].corr()
t_fa
# Out:
#           Fare       Age
# Fare  1.000000  0.171355
# Age   0.171355  1.000000

# %%
# Method 2 - seaborn
# your code here
sns.lmplot('Age','Fare',data=titanic, fit_reg=True)

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
# sns.lmplot('Age','Fare',data=t_fa, fit_reg=True)
sns.heatmap(titanic.corr(), vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
sns.scatterplot(data=titanic.corr())

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here

pclass and fares;
pclass and age;
pclass and survived

"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

sns.boxplot(titanic['Pclass'],titanic['Age'])

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
t_gender_age = sns.FacetGrid(titanic, col="Gender", col_order=['M', 'F'])
t_gender_age = t_gender_age.map(plt.hist, 'Age')

# %%
male_age = titanic.loc[titanic['Gender'] == 'male','Age']
female_age = titanic.loc[titanic['Gender'] == 'female', 'Age']
fig, gen_age = plt.subplots(1,2,figsize=(10,5))
gen_age[0].hist(male_age,color='brown')
gen_age[0].set_title('Gender = M',fontsize=30,color='brown')
gen_age[1].hist(female_age,color='purple')
gen_age[1].set_title('Gender = F',fontsize=30,color='purple')
plt.show()

# %%
# your code here
t_gender_age = sns.FacetGrid(titanic, col="Gender", col_order=['M', 'F'])
t_gender_age.map(plt.hist, 'Age')

# %%
# your code here
t_gender_age = sns.FacetGrid(titanic, col="Gender")
t_gender_age.map(plt.hist, 'Age')
